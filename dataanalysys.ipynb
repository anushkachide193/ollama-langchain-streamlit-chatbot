# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt



data ={
    "Name":["Anu","Bittu","Chinu","Dinu","Esha"],
    "Math":[78,67,90,56,88],
    "Science":[85,72,95,60,85],
    "English":[88,70,92,58,86]}
# Out:
# Running cells with 'Python 3.14.3' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/ASUS/Desktop/project Gen Ai/venv/bin/python.exe" -m pip install ipykernel -U --user --force-reinstall'
