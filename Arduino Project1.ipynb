# %%
# Data Loading 
from langchain_community.document_loaders import PyPDFLoader
docs=PyPDFLoader("A000066-datasheet.pdf")
text_loader=docs.load()
print(text_loader[0])
# Out:
# page_content='User Manual
# SKU: A000066
# Description
# The Arduino® UNO R3 is the perfect board to get familiar with electronics and coding. This versatile development
# board is equipped with the well-known ATmega328P and the ATMega 16U2 Processor.
# This board will give you a great ﬁrst experience within the world of Arduino.
# Target areas:
# Maker, introduction, industries
# Arduino® UNO R3
# 1 / 26 Arduino® UNO R3 Modiﬁed: 17/08/2026' metadata={'producer': 'Skia/PDF m151', 'creator': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) HeadlessChrome/151.0.0.0 Safari/537.36', 'creationdate': '2026-08-17T06:56:00+00:00', 'title': 'localhost:8123/A000066/haz7a-datasheet.html', 'moddate': '2026-08-17T06:56:00+00:00', 'source': 'A000066-datasheet.pdf', 'total_pages': 26, 'page': 0, 'page_label': '1'}

# %%
# document splitting
from langchain_text_splitters import RecursiveCharacterTextSplitter
textSplitter = RecursiveCharacterTextSplitter(chunk_size=200,chunk_overlap=20)
final_documents=textSplitter.split_documents(text_loader)
print(final_documents[0])
# Out:
# page_content='User Manual
# SKU: A000066
# Description
# The Arduino® UNO R3 is the perfect board to get familiar with electronics and coding. This versatile development' metadata={'producer': 'Skia/PDF m151', 'creator': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) HeadlessChrome/151.0.0.0 Safari/537.36', 'creationdate': '2026-08-17T06:56:00+00:00', 'title': 'localhost:8123/A000066/haz7a-datasheet.html', 'moddate': '2026-08-17T06:56:00+00:00', 'source': 'A000066-datasheet.pdf', 'total_pages': 26, 'page': 0, 'page_label': '1'}

# %%
from langchain_huggingface import HuggingFaceEmbeddings
embeddings=HuggingFaceEmbeddings(model_name='all-MiniLM-L6-v2')
# Out:
# ...
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 3613.87it/s]

# %%
# Embedding and vector store in DB
from langchain_community.vectorstores import FAISS
db=FAISS.from_documents(final_documents,embeddings)
db

# %%
# Retrieval (Linearity Search)
query=input("Enter Your Questions For Arduino:")
docs=db.similarity_search(query)
for i in range(len(docs)):
    print(docs[i].page_content)
# Out:
# and documented board; UNO. It is equipped with the well-known ATmega328P processor, 14 digital input/output
# Y1 ECS-160-20-4X-DU Oscillator
# 3.2 Processor
# The Main Processor is a ATmega328P running at up to 20 MHz. Most of its pins are connected to the external
# board is equipped with the well-known ATmega328P and the ATMega 16U2 Processor.
# This board will give you a great ﬁrst experience within the world of Arduino.
# Target areas:
# 2.2 Power Consumption
# 3 Functional Overview
# 3.1 Board Topology
# 3.2 Processor
# 3.3 Power Tree
# 4 Board Operation
# 4.1 Getting Started - IDE
# 4.2 Getting Started - Arduino Cloud Editor
# 4.3 Sample Sketches
